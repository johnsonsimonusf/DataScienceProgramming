# %% [markdown]
# # ICP01 Jupyter Installation
# ## Johnson Simon

# %% [markdown]
# ![MicrosoftTeams-image%20%282%29.png](attachment:MicrosoftTeams-image%20%282%29.png)
#
# INTRODUCTION:
# I am Johnson Simon, a graduate student at USF majoring in Business Analytics and Information Systems.
# I have an undergraduate degree in Information Technology from India and am currently working with USF IT as an AV Technician.
#
# Before moving to the US to pursue my master’s degree, I worked with Oracle for over 3 years as a Software Developer and Applications Engineer. I am well-versed in Oracle SQL, Java, Automation, APIs, and Dashboard development.
#
# During my tenure with Oracle, I’ve led a team of 3 and successfully completed two projects in an efficient manner. The first project Unifier Advisor - determined the database anomalies and database corruptions, helping the development and support teams reduce the turnaround time by over 70%. The dashboard development project stored and helped automation teams track the run results of different builds for various customers by providing filters. Managers can track team work progress and status by clicking a button and notifying users of a build failure.
#
# I’ve realized my interest in data, managing people, and getting the job done, which inspires me to become a Data / Business Analyst.

# %%
print('Hello World!')
# Out:
# Hello World!
